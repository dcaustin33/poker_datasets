# %%
import random

import pandas as pd
from hand_to_text import convert_hand_to_narratives
from pokerbench_translator import create_pokerkit_state_postflop
from verify_pokerkit_hand import create_state, verify_hand

df = pd.read_csv("/Users/derek/Desktop/poker_datasets/datasets/postflop_500k_train_set_game_scenario_information.csv")


random_number = random.randint(0, len(df))

issue_hands = []

# for i in range(len(df)):
#     idx = i
#     hand_history = create_pokerkit_state_postflop(df.iloc[idx])
#     if not verify_hand(hand_history.actions, hand_history.blinds_or_straddles[0], hand_history.starting_stacks):
#         issue_hands.append(idx)
#         break

# %%
# portion to check individual hands
idx = 0
print(df.iloc[idx]['preflop_action'])
print(df.iloc[idx]['postflop_action'])
print(df.iloc[idx]['correct_decision'])
print(df.iloc[idx]['hero_position'])
print(df.iloc[idx])

hand_history = create_pokerkit_state_postflop(df.iloc[idx])
print(hand_history.actions)
print("\nHand verified", verify_hand(
    hand_history.actions, hand_history.blinds_or_straddles[0], hand_history.starting_stacks
), "\n")
# starting_stacks = hand
narratives = convert_hand_to_narratives(hand_history)
for i in range(1, 7):
    if i in narratives:
        print(narratives[i])
        print("-"*100)
        break
# Out:
# HJ/2.0bb/BB/call
# OOP_CHECK/IP_BET_1/OOP_CALL/dealcards/4d/OOP_CHECK/IP_BET_8/OOP_CALL/dealcards/As/OOP_CHECK
# Check
# IP
# Unnamed: 0                                                            0
# preflop_action                                         HJ/2.0bb/BB/call
# board_flop                                                       JcJh4s
# board_turn                                                           4d
# board_river                                                          As
# aggressor_position                                                  OOP
# postflop_action       OOP_CHECK/IP_BET_1/OOP_CALL/dealcards/4d/OOP_C...
# evaluation_at                                                     River
# available_moves                                     ['Check', 'Bet 17']
# pot_size                                                             21
# hero_position                                                        IP
# holding                                                            AhKd
# correct_decision                                                  Check
# Name: 0, dtype: object
# ['d dh p1 ????', 'd dh p2 ????', 'd dh p3 ????', 'd dh p4 AhKd', 'd dh p5 ????', 'd dh p6 ????', 'p3 fold', 'p4 cbr 2.0', 'p5 fold', 'p6 fold', 'p1 fold', 'p2 cc', 'd db JcJh4s', 'p2 cc', 'p4 cbr 1.0', 'p2 cc', 'd db 4d', 'p2 cc', 'p4 cbr 8.0', 'p2 cc', 'd db As', 'p2 cc', 'p4 cc']
# Error translating action 'p4 cc' into state: An unknown card is shown.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 11
#       9 hand_history = create_pokerkit_state_postflop(df.iloc[idx])
#      10 print(hand_history.actions)
# ---> 11 print("\nHand verified", verify_hand(
#      12     hand_history.actions, hand_history.blinds_or_straddles[0], hand_history.starting_stacks
#      13 ), "\n")
#      14 # starting_stacks = hand
#      15 narratives = convert_hand_to_narratives(hand_history)
#
# File ~/Desktop/poker_datasets/poker_datasets/verify_pokerkit_hand.py:103, in verify_hand(actions, small_blind, starting_stacks)
#     101     except Exception as e:
#     102         print(f"Error translating action '{action}' into state: {e}")
# --> 103         raise e
#     104         return False
#     105 return True
#
# File ~/Desktop/poker_datasets/poker_datasets/verify_pokerkit_hand.py:100, in verify_hand(actions, small_blind, starting_stacks)
#      98 for action in filtered_actions:
#      99     try:
# --> 100         state = translate_action_into_state(action, state)
#     101     except Exception as e:
#     102         print(f"Error translating action '{action}' into state: {e}")
#
# File ~/Desktop/poker_datasets/poker_datasets/verify_pokerkit_hand.py:71, in translate_action_into_state(action, state)
#      69     state.complete_bet_or_raise_to(float(split_action[2]))
#      70 elif split_action[1] == "cc":
# ---> 71     state.check_or_call()
#      72 else:
#      73     raise ValueError(f"Invalid action: {action}")
#
# File ~/Desktop/poker_datasets/.venv/lib/python3.11/site-packages/pokerkit/state.py:4551, in State.check_or_call(self, commentary)
#    4543 self.payoffs[player_index] -= amount
#    4545 operation = CheckingOrCalling(
#    4546     player_index,
#    4547     amount,
#    4548     commentary=commentary,
#    4549 )
# -> 4551 self._update_betting(operation)
#    4553 return operation
#
# File ~/Desktop/poker_datasets/.venv/lib/python3.11/site-packages/pokerkit/state.py:4269, in State._update_betting(self, operation, status)
#    4266 self._update(operation)
#    4268 if not self.actor_indices or sum(self.statuses) <= 1 or status:
# -> 4269     self._end_betting()
#
# File ~/Desktop/poker_datasets/.venv/lib/python3.11/site-packages/pokerkit/state.py:4294, in State._end_betting(self)
#    4291 if not all(self.stacks) and self.street_index == len(self.streets) - 1:
#    4292     self.all_in_status = True
# -> 4294 self._begin_bet_collection()
#
# File ~/Desktop/poker_datasets/.venv/lib/python3.11/site-packages/pokerkit/state.py:3122, in State._begin_bet_collection(self)
#    3118 assert not self.bet_collection_status
#    3120 self.bet_collection_status = any(self.bets)
# -> 3122 self._update_bet_collection()
#
# File ~/Desktop/poker_datasets/.venv/lib/python3.11/site-packages/pokerkit/state.py:3131, in State._update_bet_collection(self, operation)
#    3128 self._update(operation)
#    3130 if not self.bet_collection_status:
# -> 3131     self._end_bet_collection()
#    3132 elif Automation.BET_COLLECTION in self.automations:
#    3133     if self.bet_collection_status:
#
# File ~/Desktop/poker_datasets/.venv/lib/python3.11/site-packages/pokerkit/state.py:3150, in State._end_bet_collection(self)
#    3148     self._begin_blind_or_straddle_posting()
#    3149 elif self.street is self.streets[-1] or self.all_in_status:
# -> 3150     self._begin_showdown()
#    3151 else:
#    3152     self._begin_dealing()
#
# File ~/Desktop/poker_datasets/.venv/lib/python3.11/site-packages/pokerkit/state.py:5102, in State._begin_showdown(self)
#    5099     if not self.statuses[i] or all(self.hole_card_statuses[i]):
#    5100         self.showdown_indices.remove(i)
# -> 5102 self._update_showdown()
#
# File ~/Desktop/poker_datasets/.venv/lib/python3.11/site-packages/pokerkit/state.py:5122, in State._update_showdown(self, operation)
#    5120 if Automation.HOLE_CARDS_SHOWING_OR_MUCKING in self.automations:
#    5121     while self.showdown_indices:
# -> 5122         self.show_or_muck_hole_cards()
#
# File ~/Desktop/poker_datasets/.venv/lib/python3.11/site-packages/pokerkit/state.py:5672, in State.show_or_muck_hole_cards(self, status_or_hole_cards, player_index, commentary)
#    5639 def show_or_muck_hole_cards(
#    5640         self,
#    5641         status_or_hole_cards: bool | CardsLike | None = None,
#    (...)   5644         commentary: str | None = None,
#    5645 ) -> HoleCardsShowingOrMucking:
#    5646     """Show or muck hole cards.
#    5647
#    5648     If the status is of type ``bool``, the hole cards of the
#    (...)   5669     :return: The hole cards showing or mucking.
#    5670     """
#    5671     status, cards, hole_cards, hole_card_statuses, player_index = (
# -> 5672         self.verify_hole_cards_showing_or_mucking(
#    5673             status_or_hole_cards,
#    5674             player_index,
#    5675         )
#    5676     )
#    5678     if self.street is not None:
#    5679         self.showdown_indices.remove(player_index)
#
# File ~/Desktop/poker_datasets/.venv/lib/python3.11/site-packages/pokerkit/state.py:5502, in State.verify_hole_cards_showing_or_mucking(self, status_or_hole_cards, player_index)
#    5500 for card, card_status in zip(hole_cards, hole_card_statuses):
#    5501     if not card and card_status:
# -> 5502         raise ValueError('An unknown card is shown.')
#    5504 assert (
#    5505     not status
#    5506     or (
#    (...)   5512     )
#    5513 )
#    5514 assert (
#    5515     status
#    5516     or (not cards and not hole_cards and not hole_card_statuses)
#    5517 )
#
# ValueError: An unknown card is shown.

# %%
from hand_to_text import convert_hand_to_narratives
from pokerkit import HandHistory
import os
from verify_pokerkit_hand import verify_hand

path_to_hands = "/Users/derek/Desktop/phh-dataset/data/pluribus"

# Walk through files and find .phh files

def walk_through_hands(path_to_hands):
    for root, dirs, files in os.walk(path_to_hands):
        for file in files:
            if file.endswith('.phh'):
                phh_path = os.path.join(root, file)
                
                # Read the hand history
                with open(phh_path, 'rb') as f:
                    hand_history = HandHistory.load(f)
                    
                # Verify the hand
                try:
                    verify_hand(hand_history.actions, hand_history.blinds_or_straddles[0], hand_history.starting_stacks)
                            
                except Exception as e:
                    print(f"Error verifying hand: {e}")
                    return
walk_through_hands(path_to_hands)

# %%
from pokerkit import HandHistory
from verify_pokerkit_hand import verify_hand

phh_phile = "/Users/derek/Desktop/phh-dataset/data/pluribus/61/18.phh"

with open(phh_phile, "rb") as file:
    hh = HandHistory.load(file)

print(hh.actions)
print(hh.blinds_or_straddles)
print(hh.starting_stacks)

print(verify_hand(hh.actions, hh.blinds_or_straddles[0], hh.starting_stacks))
# Out:
# ['d dh p1 3s3h', 'd dh p2 Qd4s', 'd dh p3 5dKc', 'd dh p4 8cJd', 'd dh p5 9hAs', 'd dh p6 4dKh', 'p3 f', 'p4 f', 'p5 cbr 250', 'p6 f', 'p1 cc', 'p2 f', 'd db 9d7c3d', 'p1 cc', 'p5 cbr 500', 'p1 cbr 1700', 'p5 cbr 9750', 'p1 cc', 'p5 sm 9hAs', 'p1 sm 3s3h', 'd db Jh', 'd db Qs']
# [50, 100, 0, 0, 0, 0]
# [10000, 10000, 10000, 10000, 10000, 10000]
# ['d dh p1 3s3h', 'd dh p2 Qd4s', 'd dh p3 5dKc', 'd dh p4 8cJd', 'd dh p5 9hAs', 'd dh p6 4dKh', 'p3 f', 'p4 f', 'p5 cbr 250', 'p6 f', 'p1 cc', 'p2 f', 'd db 9d7c3d', 'p1 cc', 'p5 cbr 500', 'p1 cbr 1700', 'p5 cbr 9750', 'p1 cc', 'd db Jh', 'd db Qs']
# True
